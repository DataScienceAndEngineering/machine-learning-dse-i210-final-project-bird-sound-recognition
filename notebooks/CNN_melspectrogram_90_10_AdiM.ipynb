# %%
import pandas as pd
import os
import numpy as np
import librosa
import tensorflow as tf
import matplotlib.pyplot as plt
import librosa.display
from sklearn.model_selection import train_test_split
import keras
from keras import Model, Input
from keras.layers import Conv1D, Flatten, Dense, Dropout, SpatialDropout1D, GlobalAveragePooling1D
from keras.optimizers import Adam
from keras.optimizers.schedules import ExponentialDecay
from keras.losses import SparseCategoricalCrossentropy
from keras.metrics import SparseCategoricalAccuracy
from sklearn.metrics import average_precision_score, f1_score, precision_score, recall_score, roc_auc_score
from keras.callbacks import TensorBoard, ModelCheckpoint
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
#tf.debugging.set_log_device_placement(True)
# Out:
# Num GPUs Available:  1

# %%
metadata = pd.read_csv('/content/drive/MyDrive/archive (17)/bird_songs_metadata.csv')
metadata.head()
# Out:
#        id       genus   species subspecies           name  \
# 0  557838  Thryomanes  bewickii        NaN  Bewick's Wren
# 1  557838  Thryomanes  bewickii        NaN  Bewick's Wren
# 2  557838  Thryomanes  bewickii        NaN  Bewick's Wren
# 3  557838  Thryomanes  bewickii        NaN  Bewick's Wren
# 4  557838  Thryomanes  bewickii        NaN  Bewick's Wren
#
#                 recordist        country  \
# 0  Whitney Neufeld-Kaiser  United States
# 1  Whitney Neufeld-Kaiser  United States
# 2  Whitney Neufeld-Kaiser  United States
# 3  Whitney Neufeld-Kaiser  United States
# 4  Whitney Neufeld-Kaiser  United States
#
#                                   location  latitude  longitude altitude  \
# 0  Arlington, Snohomish County, Washington   48.0708  -122.1006      100
# 1  Arlington, Snohomish County, Washington   48.0708  -122.1006      100
# 2  Arlington, Snohomish County, Washington   48.0708  -122.1006      100
# 3  Arlington, Snohomish County, Washington   48.0708  -122.1006      100
# 4  Arlington, Snohomish County, Washington   48.0708  -122.1006      100
#
#                    sound_type                   source_url  \
# 0  adult, sex uncertain, song  //www.xeno-canto.org/557838
# 1  adult, sex uncertain, song  //www.xeno-canto.org/557838
# 2  adult, sex uncertain, song  //www.xeno-canto.org/557838
# 3  adult, sex uncertain, song  //www.xeno-canto.org/557838
# 4  adult, sex uncertain, song  //www.xeno-canto.org/557838
#
#                                         license   time        date  \
# 0  //creativecommons.org/licenses/by-nc-sa/4.0/  11:51  2020-03-14
# 1  //creativecommons.org/licenses/by-nc-sa/4.0/  11:51  2020-03-14
# 2  //creativecommons.org/licenses/by-nc-sa/4.0/  11:51  2020-03-14
# 3  //creativecommons.org/licenses/by-nc-sa/4.0/  11:51  2020-03-14
# 4  //creativecommons.org/licenses/by-nc-sa/4.0/  11:51  2020-03-14
#
#                                              remarks      filename
# 0  Recorded with Voice Record Pro on iPhone7, nor...  557838-0.wav
# 1  Recorded with Voice Record Pro on iPhone7, nor...  557838-1.wav
# 2  Recorded with Voice Record Pro on iPhone7, nor...  557838-4.wav
# 3  Recorded with Voice Record Pro on iPhone7, nor...  557838-5.wav
# 4  Recorded with Voice Record Pro on iPhone7, nor...  557838-6.wav

# %%
# Lists for storing the filepaths and labels
file_paths = []
labels = []

audio_dir = '/content/drive/MyDrive/archive (17)/wavfiles/'

for index, row in metadata.iterrows():
    file_path = os.path.join(audio_dir, row['filename'])
    if os.path.exists(file_path):
        file_paths.append(file_path)
        labels.append(row['species'])

file_paths[:5], labels[:5]
# Out:
# (['/content/drive/MyDrive/archive (17)/wavfiles/557838-0.wav',
#   '/content/drive/MyDrive/archive (17)/wavfiles/557838-1.wav',
#   '/content/drive/MyDrive/archive (17)/wavfiles/557838-4.wav',
#   '/content/drive/MyDrive/archive (17)/wavfiles/557838-5.wav',
#   '/content/drive/MyDrive/archive (17)/wavfiles/557838-6.wav'],
#  ['bewickii', 'bewickii', 'bewickii', 'bewickii', 'bewickii'])

# %%
# Converting labels to numeric
label_dict = {label: index for index, label in enumerate(set(labels))}
y = np.array([label_dict[label] for label in labels])
y[:5]
# Out:
# array([3, 3, 3, 3, 3])

# %%
# Function to read audio file
def read_file(path):
    y, _ = librosa.load(path, sr=22050)  # Set the sample rate to ensure consistency
    return y

# Function to convert to dB scale
def spec_to_db(y):
    y_db = librosa.power_to_db(y, ref=np.max)
    #y_db = librosa.amplitude_to_db(y, ref=100)
    return y_db

# Map function that returns spectrograms
def map_function(path_tensor, label):
    # Load audio file
    y = tf.numpy_function(read_file, inp=[path_tensor], Tout=tf.float32)

    # Compute the Short-Time Fourier Transform (STFT)
    spectrogram = tf.abs(tf.signal.stft(y, frame_length=512, frame_step=64))

    mel_weights = tf.signal.linear_to_mel_weight_matrix(
        num_mel_bins=128,
        num_spectrogram_bins=tf.shape(spectrogram)[-1],
        sample_rate=22050,
        lower_edge_hertz=0.0,
        upper_edge_hertz=8000.0)
    mel_spectrogram = tf.matmul(spectrogram, mel_weights)

    # Convert to dB scale
    #log_mel_spectrogram = tf.numpy_function(spec_to_db, inp=[mel_spectrogram], Tout=tf.float32)

    #spectrogram_db = tf.numpy_function(spec_to_db, inp = [spectrogram], Tout = tf.float32)
    #spectrogram_db = spectrogram_db/80+1

    return mel_spectrogram, label


def make_dataset(labels, file_paths, shuffle):
    dataset = tf.data.Dataset.from_tensor_slices((file_paths, labels))
    if shuffle:
        dataset = dataset.shuffle(buffer_size=dataset.cardinality(), reshuffle_each_iteration=True)
    dataset = dataset.map(map_function, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.batch(batch_size=64, drop_remainder=True).prefetch(tf.data.AUTOTUNE)
    return dataset

# %%
file_paths_train, file_paths_test, y_train, y_test = train_test_split(
    file_paths, y, test_size=0.10, random_state=2419)

dataset_train = make_dataset(y_train, file_paths_train, shuffle=True)
dataset_test = make_dataset(y_test, file_paths_test, shuffle=False)

for batch in dataset_train.take(1):
    input_data_shape = batch[0].shape
print("Shape of input data in training dataset:", input_data_shape)
# Out:
# Shape of input data in training dataset: (64, 1026, 128)

# %%
def create_model():
    inputs = Input((1026, 128), name = '0_Input_shape')

    x = Conv1D(64,8,2, activation='relu', padding='same', name = '1_Conv1D')(inputs)
    x = SpatialDropout1D(0.17, name = '2_SpatialDropout1D')(x)

    x = Conv1D(64,8,2, activation='relu', padding='same', name = '3_Conv1d')(x)
    x = SpatialDropout1D(0.17, name = '4_SpatialDropout1D')(x)

    x = Conv1D(64,8,2, activation='relu', padding='same', name = '5_Conv1d')(x)
    x = SpatialDropout1D(0.17, name = '6_SpatialDropout1D')(x)

    x = Conv1D(64,8,2, activation='relu', padding='same', name = '7_Conv1d')(x)
    x = SpatialDropout1D(0.17, name = '8_SpatialDropout1D')(x)

    x = GlobalAveragePooling1D(name = '9_Global_avg_pooling')(x)
    x = Dense(512, activation='relu', name='10_Dense')(x)
    x = Dropout(0.5, name='11_Dropout')(x)
    outputs = Dense(5, name='12_Dense')(x)
    model = Model(inputs=inputs, outputs=outputs, name = 'Bird_audio_classification_model')

    return model

# %%
model = create_model()
model.summary()
# Out:
# Model: "Bird_audio_classification_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  0_Input_shape (InputLayer)  [(None, 1026, 128)]       0
#
#  1_Conv1D (Conv1D)           (None, 513, 64)           65600
#
#  2_SpatialDropout1D (Spatia  (None, 513, 64)           0
#  lDropout1D)
#
#  3_Conv1d (Conv1D)           (None, 257, 64)           32832
#
#  4_SpatialDropout1D (Spatia  (None, 257, 64)           0
#  lDropout1D)
#
#  5_Conv1d (Conv1D)           (None, 129, 64)           32832
#
#  6_SpatialDropout1D (Spatia  (None, 129, 64)           0
#  lDropout1D)
#
#  7_Conv1d (Conv1D)           (None, 65, 64)            32832
#
#  8_SpatialDropout1D (Spatia  (None, 65, 64)            0
#  lDropout1D)
#
#  9_Global_avg_pooling (Glob  (None, 64)                0
#  alAveragePooling1D)
#
#  10_Dense (Dense)            (None, 512)               33280
#
#  11_Dropout (Dropout)        (None, 512)               0
#
#  12_Dense (Dense)            (None, 5)                 2565
#
# =================================================================
# Total params: 199941 (781.02 KB)
# Trainable params: 199941 (781.02 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
lr_schedule = ExponentialDecay(initial_learning_rate=1e-3,
                               decay_steps= 4000, decay_rate = 0.5, staircase=False, name=None)

model.compile(optimizer = Adam(lr_schedule),
              loss = SparseCategoricalCrossentropy(from_logits = True),
              metrics = [ SparseCategoricalAccuracy()])

# %%
# Creating callbacks
logdir = 'tb_logs/model'
tensorboard_callback = TensorBoard(log_dir=logdir)

checkpoint_filepath = 'model_checkpoint/model'
model_checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_sparse_categorical_accuracy',
    mode='max',
    save_best_only=True)

# %%
training = model.fit(dataset_train, validation_data = dataset_test, epochs=120,
                    callbacks=[tensorboard_callback,model_checkpoint_callback])
# Out:
# Epoch 1/120
# 76/76 [==============================] - 42s 500ms/step - loss: 1.2699 - sparse_categorical_accuracy: 0.4198 - val_loss: 0.9642 - val_sparse_categorical_accuracy: 0.5742
# Epoch 2/120
# 76/76 [==============================] - 42s 560ms/step - loss: 0.9825 - sparse_categorical_accuracy: 0.5987 - val_loss: 0.7258 - val_sparse_categorical_accuracy: 0.7773
# Epoch 3/120
# 76/76 [==============================] - 38s 495ms/step - loss: 0.8276 - sparse_categorical_accuracy: 0.6949 - val_loss: 0.6356 - val_sparse_categorical_accuracy: 0.7949
# Epoch 4/120
# 76/76 [==============================] - 40s 526ms/step - loss: 0.7331 - sparse_categorical_accuracy: 0.7377 - val_loss: 0.6008 - val_sparse_categorical_accuracy: 0.8145
# Epoch 5/120
# 76/76 [==============================] - 40s 525ms/step - loss: 0.6329 - sparse_categorical_accuracy: 0.7786 - val_loss: 0.4758 - val_sparse_categorical_accuracy: 0.8379
# Epoch 6/120
# 76/76 [==============================] - 38s 499ms/step - loss: 0.5518 - sparse_categorical_accuracy: 0.8102 - val_loss: 0.4189 - val_sparse_categorical_accuracy: 0.8516
# Epoch 7/120
# 76/76 [==============================] - 39s 518ms/step - loss: 0.4900 - sparse_categorical_accuracy: 0.8289 - val_loss: 0.3558 - val_sparse_categorical_accuracy: 0.8789
# Epoch 8/120
# 76/76 [==============================] - 42s 553ms/step - loss: 0.4685 - sparse_categorical_accuracy: 0.8370 - val_loss: 0.3247 - val_sparse_categorical_accuracy: 0.9043
# Epoch 9/120
# 76/76 [==============================] - 43s 567ms/step - loss: 0.4137 - sparse_categorical_accuracy: 0.8588 - val_loss: 0.3060 - val_sparse_categorical_accuracy: 0.9082
# Epoch 10/120
# 76/76 [==============================] - 38s 501ms/step - loss: 0.4063 - sparse_categorical_accuracy: 0.8588 - val_loss: 0.2893 - val_sparse_categorical_accuracy: 0.9121
# Epoch 11/120
# 76/76 [==============================] - 37s 482ms/step - loss: 0.3686 - sparse_categorical_accuracy: 0.8699 - val_loss: 0.2573 - val_sparse_categorical_accuracy: 0.9121
# Epoch 12/120
# 76/76 [==============================] - 41s 544ms/step - loss: 0.3617 - sparse_categorical_accuracy: 0.8760 - val_loss: 0.2168 - val_sparse_categorical_accuracy: 0.9297
# Epoch 13/120
# 76/76 [==============================] - 40s 527ms/step - loss: 0.3151 - sparse_categorical_accuracy: 0.8921 - val_loss: 0.1996 - val_sparse_categorical_accuracy: 0.9336
# Epoch 14/120
# 76/76 [==============================] - 41s 543ms/step - loss: 0.3028 - sparse_categorical_accuracy: 0.8997 - val_loss: 0.1991 - val_sparse_categorical_accuracy: 0.9355
# Epoch 15/120
# 76/76 [==============================] - 40s 527ms/step - loss: 0.2897 - sparse_categorical_accuracy: 0.9019 - val_loss: 0.1836 - val_sparse_categorical_accuracy: 0.9395
# Epoch 16/120
# 76/76 [==============================] - 38s 498ms/step - loss: 0.2627 - sparse_categorical_accuracy: 0.9130 - val_loss: 0.1540 - val_sparse_categorical_accuracy: 0.9531
# Epoch 17/120
# 76/76 [==============================] - 38s 506ms/step - loss: 0.2445 - sparse_categorical_accuracy: 0.9213 - val_loss: 0.1639 - val_sparse_categorical_accuracy: 0.9473
# Epoch 18/120
# 76/76 [==============================] - 37s 488ms/step - loss: 0.2310 - sparse_categorical_accuracy: 0.9180 - val_loss: 0.1663 - val_sparse_categorical_accuracy: 0.9512
# Epoch 19/120
# 76/76 [==============================] - 36s 481ms/step - loss: 0.2362 - sparse_categorical_accuracy: 0.9239 - val_loss: 0.1600 - val_sparse_categorical_accuracy: 0.9531
# Epoch 20/120
# 76/76 [==============================] - 40s 522ms/step - loss: 0.2254 - sparse_categorical_accuracy: 0.9272 - val_loss: 0.1536 - val_sparse_categorical_accuracy: 0.9570
# Epoch 21/120
# 76/76 [==============================] - 38s 505ms/step - loss: 0.2074 - sparse_categorical_accuracy: 0.9317 - val_loss: 0.1424 - val_sparse_categorical_accuracy: 0.9531
# Epoch 22/120
# 76/76 [==============================] - 38s 503ms/step - loss: 0.1972 - sparse_categorical_accuracy: 0.9328 - val_loss: 0.1309 - val_sparse_categorical_accuracy: 0.9609
# Epoch 23/120
# 76/76 [==============================] - 36s 478ms/step - loss: 0.1876 - sparse_categorical_accuracy: 0.9365 - val_loss: 0.1259 - val_sparse_categorical_accuracy: 0.9570
# Epoch 24/120
# 76/76 [==============================] - 38s 505ms/step - loss: 0.1940 - sparse_categorical_accuracy: 0.9354 - val_loss: 0.1244 - val_sparse_categorical_accuracy: 0.9609
# Epoch 25/120
# 76/76 [==============================] - 40s 522ms/step - loss: 0.1675 - sparse_categorical_accuracy: 0.9408 - val_loss: 0.1120 - val_sparse_categorical_accuracy: 0.9629
# Epoch 26/120
# 76/76 [==============================] - 36s 478ms/step - loss: 0.1592 - sparse_categorical_accuracy: 0.9472 - val_loss: 0.1092 - val_sparse_categorical_accuracy: 0.9629
# Epoch 27/120
# 76/76 [==============================] - 39s 510ms/step - loss: 0.1496 - sparse_categorical_accuracy: 0.9492 - val_loss: 0.1318 - val_sparse_categorical_accuracy: 0.9570
# Epoch 28/120
# 76/76 [==============================] - 40s 531ms/step - loss: 0.1478 - sparse_categorical_accuracy: 0.9509 - val_loss: 0.1085 - val_sparse_categorical_accuracy: 0.9688
# Epoch 29/120
# 76/76 [==============================] - 39s 509ms/step - loss: 0.1426 - sparse_categorical_accuracy: 0.9548 - val_loss: 0.1252 - val_sparse_categorical_accuracy: 0.9648
# Epoch 30/120
# 76/76 [==============================] - 39s 513ms/step - loss: 0.1331 - sparse_categorical_accuracy: 0.9529 - val_loss: 0.1183 - val_sparse_categorical_accuracy: 0.9609
# Epoch 31/120
# 76/76 [==============================] - 38s 506ms/step - loss: 0.1552 - sparse_categorical_accuracy: 0.9472 - val_loss: 0.1240 - val_sparse_categorical_accuracy: 0.9629
# Epoch 32/120
# 76/76 [==============================] - 39s 516ms/step - loss: 0.1323 - sparse_categorical_accuracy: 0.9554 - val_loss: 0.1131 - val_sparse_categorical_accuracy: 0.9688
# Epoch 33/120
# 76/76 [==============================] - 41s 537ms/step - loss: 0.1302 - sparse_categorical_accuracy: 0.9554 - val_loss: 0.1112 - val_sparse_categorical_accuracy: 0.9707
# Epoch 34/120
# 76/76 [==============================] - 40s 524ms/step - loss: 0.1277 - sparse_categorical_accuracy: 0.9591 - val_loss: 0.1081 - val_sparse_categorical_accuracy: 0.9688
# Epoch 35/120
# 76/76 [==============================] - 39s 521ms/step - loss: 0.1282 - sparse_categorical_accuracy: 0.9560 - val_loss: 0.1191 - val_sparse_categorical_accuracy: 0.9668
# Epoch 36/120
# 76/76 [==============================] - 40s 532ms/step - loss: 0.1199 - sparse_categorical_accuracy: 0.9579 - val_loss: 0.1128 - val_sparse_categorical_accuracy: 0.9727
# Epoch 37/120
# 76/76 [==============================] - 39s 513ms/step - loss: 0.1143 - sparse_categorical_accuracy: 0.9605 - val_loss: 0.1155 - val_sparse_categorical_accuracy: 0.9668
# Epoch 38/120
# 76/76 [==============================] - 39s 508ms/step - loss: 0.1140 - sparse_categorical_accuracy: 0.9618 - val_loss: 0.1066 - val_sparse_categorical_accuracy: 0.9668
# Epoch 39/120
# 76/76 [==============================] - 39s 509ms/step - loss: 0.1065 - sparse_categorical_accuracy: 0.9644 - val_loss: 0.1196 - val_sparse_categorical_accuracy: 0.9629
# Epoch 40/120
# 76/76 [==============================] - 38s 506ms/step - loss: 0.1119 - sparse_categorical_accuracy: 0.9632 - val_loss: 0.1139 - val_sparse_categorical_accuracy: 0.9727
# Epoch 41/120
# 76/76 [==============================] - 37s 486ms/step - loss: 0.1037 - sparse_categorical_accuracy: 0.9665 - val_loss: 0.1295 - val_sparse_categorical_accuracy: 0.9590
# Epoch 42/120
# 76/76 [==============================] - 39s 515ms/step - loss: 0.1208 - sparse_categorical_accuracy: 0.9605 - val_loss: 0.1170 - val_sparse_categorical_accuracy: 0.9668
# Epoch 43/120
# 76/76 [==============================] - 39s 513ms/step - loss: 0.1040 - sparse_categorical_accuracy: 0.9663 - val_loss: 0.1201 - val_sparse_categorical_accuracy: 0.9570
# Epoch 44/120
# 76/76 [==============================] - 37s 482ms/step - loss: 0.0985 - sparse_categorical_accuracy: 0.9692 - val_loss: 0.1115 - val_sparse_categorical_accuracy: 0.9707
# Epoch 45/120
# 76/76 [==============================] - 40s 525ms/step - loss: 0.0923 - sparse_categorical_accuracy: 0.9685 - val_loss: 0.1209 - val_sparse_categorical_accuracy: 0.9668
# Epoch 46/120
# 76/76 [==============================] - 41s 536ms/step - loss: 0.0801 - sparse_categorical_accuracy: 0.9727 - val_loss: 0.1108 - val_sparse_categorical_accuracy: 0.9727
# Epoch 47/120
# 76/76 [==============================] - 41s 539ms/step - loss: 0.0907 - sparse_categorical_accuracy: 0.9685 - val_loss: 0.1164 - val_sparse_categorical_accuracy: 0.9629
# Epoch 48/120
# 76/76 [==============================] - 38s 499ms/step - loss: 0.0907 - sparse_categorical_accuracy: 0.9692 - val_loss: 0.1174 - val_sparse_categorical_accuracy: 0.9688
# Epoch 49/120
# 76/76 [==============================] - 38s 497ms/step - loss: 0.0723 - sparse_categorical_accuracy: 0.9749 - val_loss: 0.1120 - val_sparse_categorical_accuracy: 0.9668
# Epoch 50/120
# 76/76 [==============================] - 37s 485ms/step - loss: 0.0750 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.1264 - val_sparse_categorical_accuracy: 0.9629
# Epoch 51/120
# 76/76 [==============================] - 38s 506ms/step - loss: 0.0841 - sparse_categorical_accuracy: 0.9718 - val_loss: 0.1110 - val_sparse_categorical_accuracy: 0.9688
# Epoch 52/120
# 76/76 [==============================] - 38s 507ms/step - loss: 0.0853 - sparse_categorical_accuracy: 0.9751 - val_loss: 0.1069 - val_sparse_categorical_accuracy: 0.9668
# Epoch 53/120
# 76/76 [==============================] - 38s 504ms/step - loss: 0.0743 - sparse_categorical_accuracy: 0.9762 - val_loss: 0.1020 - val_sparse_categorical_accuracy: 0.9688
# Epoch 54/120
# 76/76 [==============================] - 39s 509ms/step - loss: 0.0659 - sparse_categorical_accuracy: 0.9784 - val_loss: 0.1125 - val_sparse_categorical_accuracy: 0.9648
# Epoch 55/120
# 76/76 [==============================] - 39s 509ms/step - loss: 0.0783 - sparse_categorical_accuracy: 0.9725 - val_loss: 0.1138 - val_sparse_categorical_accuracy: 0.9668
# Epoch 56/120
# 76/76 [==============================] - 37s 491ms/step - loss: 0.0733 - sparse_categorical_accuracy: 0.9739 - val_loss: 0.1100 - val_sparse_categorical_accuracy: 0.9688
# Epoch 57/120
# 76/76 [==============================] - 40s 524ms/step - loss: 0.0727 - sparse_categorical_accuracy: 0.9743 - val_loss: 0.1231 - val_sparse_categorical_accuracy: 0.9629
# Epoch 58/120
# 76/76 [==============================] - 40s 529ms/step - loss: 0.0603 - sparse_categorical_accuracy: 0.9799 - val_loss: 0.1086 - val_sparse_categorical_accuracy: 0.9688
# Epoch 59/120
# 76/76 [==============================] - 38s 504ms/step - loss: 0.0652 - sparse_categorical_accuracy: 0.9770 - val_loss: 0.1309 - val_sparse_categorical_accuracy: 0.9668
# Epoch 60/120
# 76/76 [==============================] - 38s 505ms/step - loss: 0.0733 - sparse_categorical_accuracy: 0.9764 - val_loss: 0.1185 - val_sparse_categorical_accuracy: 0.9668
# Epoch 61/120
# 76/76 [==============================] - 38s 502ms/step - loss: 0.0736 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.1182 - val_sparse_categorical_accuracy: 0.9668
# Epoch 62/120
# 76/76 [==============================] - 39s 516ms/step - loss: 0.0700 - sparse_categorical_accuracy: 0.9759 - val_loss: 0.1078 - val_sparse_categorical_accuracy: 0.9746
# Epoch 63/120
# 76/76 [==============================] - 38s 507ms/step - loss: 0.0629 - sparse_categorical_accuracy: 0.9784 - val_loss: 0.1270 - val_sparse_categorical_accuracy: 0.9629
# Epoch 64/120
# 76/76 [==============================] - 37s 483ms/step - loss: 0.0601 - sparse_categorical_accuracy: 0.9799 - val_loss: 0.1205 - val_sparse_categorical_accuracy: 0.9668
# Epoch 65/120
# 76/76 [==============================] - 38s 499ms/step - loss: 0.0583 - sparse_categorical_accuracy: 0.9823 - val_loss: 0.1241 - val_sparse_categorical_accuracy: 0.9668
# Epoch 66/120
# 76/76 [==============================] - 39s 519ms/step - loss: 0.0592 - sparse_categorical_accuracy: 0.9778 - val_loss: 0.1129 - val_sparse_categorical_accuracy: 0.9609
# Epoch 67/120
# 76/76 [==============================] - 41s 545ms/step - loss: 0.0627 - sparse_categorical_accuracy: 0.9780 - val_loss: 0.1185 - val_sparse_categorical_accuracy: 0.9648
# Epoch 68/120
# 76/76 [==============================] - 40s 524ms/step - loss: 0.0600 - sparse_categorical_accuracy: 0.9815 - val_loss: 0.0998 - val_sparse_categorical_accuracy: 0.9727
# Epoch 69/120
# 76/76 [==============================] - 41s 545ms/step - loss: 0.0624 - sparse_categorical_accuracy: 0.9786 - val_loss: 0.0971 - val_sparse_categorical_accuracy: 0.9766
# Epoch 70/120
# 76/76 [==============================] - 40s 519ms/step - loss: 0.0618 - sparse_categorical_accuracy: 0.9801 - val_loss: 0.1097 - val_sparse_categorical_accuracy: 0.9688
# Epoch 71/120
# 76/76 [==============================] - 38s 496ms/step - loss: 0.0498 - sparse_categorical_accuracy: 0.9823 - val_loss: 0.1053 - val_sparse_categorical_accuracy: 0.9707
# Epoch 72/120
# 76/76 [==============================] - 38s 501ms/step - loss: 0.0495 - sparse_categorical_accuracy: 0.9821 - val_loss: 0.1196 - val_sparse_categorical_accuracy: 0.9746
# Epoch 73/120
# 76/76 [==============================] - 38s 500ms/step - loss: 0.0524 - sparse_categorical_accuracy: 0.9827 - val_loss: 0.1140 - val_sparse_categorical_accuracy: 0.9648
# Epoch 74/120
# 76/76 [==============================] - 38s 497ms/step - loss: 0.0462 - sparse_categorical_accuracy: 0.9873 - val_loss: 0.1082 - val_sparse_categorical_accuracy: 0.9727
# Epoch 75/120
# 76/76 [==============================] - 39s 510ms/step - loss: 0.0530 - sparse_categorical_accuracy: 0.9823 - val_loss: 0.1062 - val_sparse_categorical_accuracy: 0.9727
# Epoch 76/120
# 76/76 [==============================] - 39s 512ms/step - loss: 0.0556 - sparse_categorical_accuracy: 0.9829 - val_loss: 0.1217 - val_sparse_categorical_accuracy: 0.9668
# Epoch 77/120
# 76/76 [==============================] - 37s 493ms/step - loss: 0.0517 - sparse_categorical_accuracy: 0.9805 - val_loss: 0.1085 - val_sparse_categorical_accuracy: 0.9707
# Epoch 78/120
# 76/76 [==============================] - 38s 501ms/step - loss: 0.0478 - sparse_categorical_accuracy: 0.9842 - val_loss: 0.1157 - val_sparse_categorical_accuracy: 0.9668
# Epoch 79/120
# 76/76 [==============================] - 37s 489ms/step - loss: 0.0405 - sparse_categorical_accuracy: 0.9864 - val_loss: 0.1270 - val_sparse_categorical_accuracy: 0.9668
# Epoch 80/120
# 76/76 [==============================] - 37s 488ms/step - loss: 0.0479 - sparse_categorical_accuracy: 0.9852 - val_loss: 0.1296 - val_sparse_categorical_accuracy: 0.9668
# Epoch 81/120
# 76/76 [==============================] - 39s 513ms/step - loss: 0.0477 - sparse_categorical_accuracy: 0.9852 - val_loss: 0.1214 - val_sparse_categorical_accuracy: 0.9629
# Epoch 82/120
# 76/76 [==============================] - 40s 525ms/step - loss: 0.0437 - sparse_categorical_accuracy: 0.9848 - val_loss: 0.1294 - val_sparse_categorical_accuracy: 0.9648
# Epoch 83/120
# 76/76 [==============================] - 39s 519ms/step - loss: 0.0466 - sparse_categorical_accuracy: 0.9848 - val_loss: 0.1157 - val_sparse_categorical_accuracy: 0.9688
# Epoch 84/120
# 76/76 [==============================] - 39s 512ms/step - loss: 0.0498 - sparse_categorical_accuracy: 0.9852 - val_loss: 0.1373 - val_sparse_categorical_accuracy: 0.9688
# Epoch 85/120
# 76/76 [==============================] - 38s 504ms/step - loss: 0.0448 - sparse_categorical_accuracy: 0.9858 - val_loss: 0.1178 - val_sparse_categorical_accuracy: 0.9727
# Epoch 86/120
# 76/76 [==============================] - 38s 499ms/step - loss: 0.0391 - sparse_categorical_accuracy: 0.9881 - val_loss: 0.1155 - val_sparse_categorical_accuracy: 0.9727
# Epoch 87/120
# 76/76 [==============================] - 40s 524ms/step - loss: 0.0325 - sparse_categorical_accuracy: 0.9883 - val_loss: 0.1173 - val_sparse_categorical_accuracy: 0.9785
# Epoch 88/120
# 76/76 [==============================] - 38s 503ms/step - loss: 0.0437 - sparse_categorical_accuracy: 0.9850 - val_loss: 0.1134 - val_sparse_categorical_accuracy: 0.9746
# Epoch 89/120
# 76/76 [==============================] - 38s 503ms/step - loss: 0.0360 - sparse_categorical_accuracy: 0.9875 - val_loss: 0.1154 - val_sparse_categorical_accuracy: 0.9707
# Epoch 90/120
# 76/76 [==============================] - 38s 501ms/step - loss: 0.0357 - sparse_categorical_accuracy: 0.9868 - val_loss: 0.1074 - val_sparse_categorical_accuracy: 0.9727
# Epoch 91/120
# 76/76 [==============================] - 38s 495ms/step - loss: 0.0398 - sparse_categorical_accuracy: 0.9858 - val_loss: 0.1221 - val_sparse_categorical_accuracy: 0.9727
# Epoch 92/120
# 76/76 [==============================] - 38s 504ms/step - loss: 0.0406 - sparse_categorical_accuracy: 0.9877 - val_loss: 0.1206 - val_sparse_categorical_accuracy: 0.9785
# Epoch 93/120
# 76/76 [==============================] - 37s 484ms/step - loss: 0.0481 - sparse_categorical_accuracy: 0.9852 - val_loss: 0.1122 - val_sparse_categorical_accuracy: 0.9727
# Epoch 94/120
# 76/76 [==============================] - 37s 494ms/step - loss: 0.0489 - sparse_categorical_accuracy: 0.9854 - val_loss: 0.1115 - val_sparse_categorical_accuracy: 0.9727
# Epoch 95/120
# 76/76 [==============================] - 40s 524ms/step - loss: 0.0314 - sparse_categorical_accuracy: 0.9893 - val_loss: 0.1184 - val_sparse_categorical_accuracy: 0.9727
# Epoch 96/120
# 76/76 [==============================] - 40s 528ms/step - loss: 0.0330 - sparse_categorical_accuracy: 0.9887 - val_loss: 0.1275 - val_sparse_categorical_accuracy: 0.9668
# Epoch 97/120
# 76/76 [==============================] - 40s 524ms/step - loss: 0.0391 - sparse_categorical_accuracy: 0.9879 - val_loss: 0.1200 - val_sparse_categorical_accuracy: 0.9746
# Epoch 98/120
# 76/76 [==============================] - 38s 500ms/step - loss: 0.0481 - sparse_categorical_accuracy: 0.9870 - val_loss: 0.1116 - val_sparse_categorical_accuracy: 0.9668
# Epoch 99/120
# 76/76 [==============================] - 36s 480ms/step - loss: 0.0386 - sparse_categorical_accuracy: 0.9879 - val_loss: 0.1156 - val_sparse_categorical_accuracy: 0.9648
# Epoch 100/120
# 76/76 [==============================] - 37s 490ms/step - loss: 0.0379 - sparse_categorical_accuracy: 0.9895 - val_loss: 0.1055 - val_sparse_categorical_accuracy: 0.9746
# Epoch 101/120
# 76/76 [==============================] - 38s 503ms/step - loss: 0.0386 - sparse_categorical_accuracy: 0.9864 - val_loss: 0.1055 - val_sparse_categorical_accuracy: 0.9766
# Epoch 102/120
# 76/76 [==============================] - 37s 494ms/step - loss: 0.0352 - sparse_categorical_accuracy: 0.9899 - val_loss: 0.1090 - val_sparse_categorical_accuracy: 0.9785
# Epoch 103/120
# 76/76 [==============================] - 38s 508ms/step - loss: 0.0372 - sparse_categorical_accuracy: 0.9893 - val_loss: 0.1106 - val_sparse_categorical_accuracy: 0.9727
# Epoch 104/120
# 76/76 [==============================] - 38s 501ms/step - loss: 0.0290 - sparse_categorical_accuracy: 0.9907 - val_loss: 0.1047 - val_sparse_categorical_accuracy: 0.9727
# Epoch 105/120
# 76/76 [==============================] - 36s 478ms/step - loss: 0.0311 - sparse_categorical_accuracy: 0.9895 - val_loss: 0.1080 - val_sparse_categorical_accuracy: 0.9746
# Epoch 106/120
# 76/76 [==============================] - 37s 493ms/step - loss: 0.0405 - sparse_categorical_accuracy: 0.9852 - val_loss: 0.1059 - val_sparse_categorical_accuracy: 0.9746
# Epoch 107/120
# 76/76 [==============================] - 39s 519ms/step - loss: 0.0338 - sparse_categorical_accuracy: 0.9891 - val_loss: 0.1021 - val_sparse_categorical_accuracy: 0.9746
# Epoch 108/120
# 76/76 [==============================] - 39s 514ms/step - loss: 0.0323 - sparse_categorical_accuracy: 0.9903 - val_loss: 0.1061 - val_sparse_categorical_accuracy: 0.9785
# Epoch 109/120
# 76/76 [==============================] - 39s 517ms/step - loss: 0.0271 - sparse_categorical_accuracy: 0.9907 - val_loss: 0.1125 - val_sparse_categorical_accuracy: 0.9766
# Epoch 110/120
# 76/76 [==============================] - 39s 519ms/step - loss: 0.0370 - sparse_categorical_accuracy: 0.9875 - val_loss: 0.1222 - val_sparse_categorical_accuracy: 0.9707
# Epoch 111/120
# 76/76 [==============================] - 37s 486ms/step - loss: 0.0367 - sparse_categorical_accuracy: 0.9877 - val_loss: 0.1147 - val_sparse_categorical_accuracy: 0.9746
# Epoch 112/120
# 76/76 [==============================] - 40s 527ms/step - loss: 0.0300 - sparse_categorical_accuracy: 0.9916 - val_loss: 0.1095 - val_sparse_categorical_accuracy: 0.9805
# Epoch 113/120
# 76/76 [==============================] - 37s 489ms/step - loss: 0.0281 - sparse_categorical_accuracy: 0.9899 - val_loss: 0.1163 - val_sparse_categorical_accuracy: 0.9746
# Epoch 114/120
# 76/76 [==============================] - 38s 495ms/step - loss: 0.0288 - sparse_categorical_accuracy: 0.9912 - val_loss: 0.1152 - val_sparse_categorical_accuracy: 0.9766
# Epoch 115/120
# 76/76 [==============================] - 38s 495ms/step - loss: 0.0241 - sparse_categorical_accuracy: 0.9914 - val_loss: 0.1265 - val_sparse_categorical_accuracy: 0.9727
# Epoch 116/120
# 76/76 [==============================] - 38s 495ms/step - loss: 0.0260 - sparse_categorical_accuracy: 0.9907 - val_loss: 0.1196 - val_sparse_categorical_accuracy: 0.9727
# Epoch 117/120
# 76/76 [==============================] - 37s 489ms/step - loss: 0.0330 - sparse_categorical_accuracy: 0.9905 - val_loss: 0.1268 - val_sparse_categorical_accuracy: 0.9688
# Epoch 118/120
# 76/76 [==============================] - 38s 498ms/step - loss: 0.0288 - sparse_categorical_accuracy: 0.9901 - val_loss: 0.1249 - val_sparse_categorical_accuracy: 0.9727
# Epoch 119/120
# 76/76 [==============================] - 39s 511ms/step - loss: 0.0326 - sparse_categorical_accuracy: 0.9887 - val_loss: 0.1136 - val_sparse_categorical_accuracy: 0.9727
# Epoch 120/120
# 76/76 [==============================] - 38s 502ms/step - loss: 0.0321 - sparse_categorical_accuracy: 0.9914 - val_loss: 0.1151 - val_sparse_categorical_accuracy: 0.9785
